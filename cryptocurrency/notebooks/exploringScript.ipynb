# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url="../data/processed/output.csv"
convert_dates=["time"]
ds = pd.read_csv(url, parse_dates="true")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f42af9ae1581> in <module>()
# ----> 1 ds = pd.read_csv("../data/processed/output.csv", parse_dates="true")
#
# ...

# %%
ds.shape
# Out:
# (10885, 8)

# %%
ds.head(10)
# Out:
#   Cryptocurrency          Date   Open   High    Low  Close       Volume  \
# 0        omisego  Sep 04, 2017  10.55  10.55   7.31   8.78  159,979,000
# 1        omisego  Sep 03, 2017  10.79  11.37   9.64  10.57   68,616,800
# 2        omisego  Sep 02, 2017  11.99  11.99   9.96  10.80   93,561,000
# 3        omisego  Sep 01, 2017  11.73  12.52  11.63  11.97   91,962,400
# 4        omisego  Aug 31, 2017  11.17  12.08  10.78  11.74   89,710,200
# 5        omisego  Aug 30, 2017   9.49  11.67   9.30  11.07  194,613,000
# 6        omisego  Aug 29, 2017   8.58   9.62   8.45   9.46   86,155,000
# 7        omisego  Aug 28, 2017   8.33   8.93   8.15   8.59   52,390,300
# 8        omisego  Aug 27, 2017   8.29   8.37   8.03   8.33   22,915,000
# 9        omisego  Aug 26, 2017   8.26   8.33   7.85   8.28   25,661,900
#
#       Market Cap
# 0  1,037,440,000
# 1  1,060,760,000
# 2  1,178,610,000
# 3  1,153,390,000
# 4  1,098,470,000
# 5    932,958,000
# 6    843,249,000
# 7    819,005,000
# ...

# %%
ds["Cryptocurrency"].value_counts()
# Out:
# litecoin            1591
# bitcoin             1591
# ripple              1493
# dash                1299
# monero              1202
# nem                  888
# ethereum             760
# waves                460
# ethereum_classic     408
# stratis              389
# neo                  361
# bitconnect           228
# iota                  84
# bitcoin_cash          44
# qtum                  29
# numeraire             29
# omisego               29
# Name: Cryptocurrency, dtype: int64

# %%
ds.describe(include="all")
# Out:
#        Cryptocurrency          Date          Open          High           Low  \
# count           10885         10885  10885.000000  10885.000000  10885.000000
# unique             17          1591           NaN           NaN           NaN
# top          litecoin  Aug 22, 2017           NaN           NaN           NaN
# freq             1591            17           NaN           NaN           NaN
# mean              NaN           NaN    107.771067    111.222251    104.575532
# std               NaN           NaN    359.214521    371.009992    348.291826
# min               NaN           NaN      0.000086      0.000089      0.000079
# 25%               NaN           NaN      0.187457      0.200834      0.177627
# 50%               NaN           NaN      2.820000      2.930000      2.690000
# 75%               NaN           NaN     15.100000     15.840000     14.230000
# max               NaN           NaN   4901.420000   4975.040000   4678.530000
#
# ...
