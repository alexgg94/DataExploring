# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ds = pd.read_csv("sorted_output.csv")

# %%
ds["sensor"].value_counts()
# Out:
# DHT22     1522253
# HTU21     1510105
# BMP280    1504469
# DHT11     1501874
# DM280           5
# Name: sensor, dtype: int64

# %%
ds.shape
# Out:
# (6038706, 5)

# %%
ds.describe(include="all")
# Out:
#                        time   sensor             H             P             T
# count               6038706  6038706  4.288839e+06  1.422792e+06  5.711640e+06
# unique              5943769        5           NaN           NaN           NaN
# top     2018-03-13 11:35:48    DHT22           NaN           NaN           NaN
# freq                      4  1522253           NaN           NaN           NaN
# mean                    NaN      NaN  2.336465e+01  1.015690e+03  2.201185e+01
# std                     NaN      NaN  1.617257e+01  1.011069e+01  2.631197e+00
# min                     NaN      NaN  1.000000e+00  9.856200e+02  1.500000e+01
# 25%                     NaN      NaN  1.000000e+00  1.008670e+03  2.063000e+01
# 50%                     NaN      NaN  3.360000e+01  1.016970e+03  2.211000e+01
# 75%                     NaN      NaN  3.500000e+01  1.022570e+03  2.393000e+01
# max                     NaN      NaN  9.990000e+01  1.040000e+03  2.980000e+01

# %%
ds.isnull().values.any()
# Out:
# True

# %%
ds.replace({"sensor" : {"DHT22" : 0, "DHT22" : 1, "HTU21" : 2, "HTU21" : 3, "BMP280" : 4, "BMP280" : 5, "DHT11" : 6, "DHT11" : 7, "DM280" : 8, "DM280" : 9}}, inplace=True)
colors = np.array(["red", "blue", "green", "orange", "black", "gray", "pink", "purple", "yellow", "brown"])

# %%
ds.head(20)
# Out:
#                    time  sensor     H   P     T
# 0   2017-12-19 14:07:18       1  15.7 NaN  25.5
# 1   2017-12-19 14:07:25       1  15.7 NaN  25.5
# 2   2017-12-19 14:07:32       1  15.7 NaN  25.6
# 3   2017-12-19 14:07:38       1  15.7 NaN  25.6
# 4   2017-12-19 14:07:45       1  15.7 NaN  25.6
# 5   2017-12-19 14:07:52       1  15.8 NaN  25.6
# 6   2017-12-19 14:07:59       1  16.3 NaN  25.6
# 7   2017-12-19 14:08:06       1  16.1 NaN  25.5
# 8   2017-12-19 14:08:12       1  16.5 NaN  25.5
# 9   2017-12-19 14:08:19       1  15.8 NaN  25.5
# 10  2017-12-19 14:08:26       1  15.7 NaN  25.5
# 11  2017-12-19 14:08:33       1  15.8 NaN  25.5
# 12  2017-12-19 14:08:39       1  15.7 NaN  25.5
# 13  2017-12-19 14:08:46       1  15.7 NaN  25.5
# 14  2017-12-19 14:08:53       1  15.8 NaN  25.5
# 15  2017-12-19 14:09:00       1  15.8 NaN  25.5
# 16  2017-12-19 14:09:06       1   NaN NaN  25.6
# 17  2017-12-19 14:09:07       1  15.9 NaN   NaN
# 18  2017-12-19 14:09:13       1  16.2 NaN  25.5
# ...

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size

# %%
data = ds.head(30)
plt.scatter(data["H"], data["time"], c = colors[ds["sensor"]], s=40)

plt.show()

# %%
plt.scatter(data["P"], data["time"], c = colors[ds["sensor"]], s=40)

plt.show()

# %%
plt.scatter(data["T"], data["time"], c = colors[ds["sensor"]], s=40)

plt.show()
